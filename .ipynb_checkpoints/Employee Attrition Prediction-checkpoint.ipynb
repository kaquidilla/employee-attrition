# %%
# Import libraries for data operations
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from imblearn.over_sampling import SMOTE

# Import libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Import libraries for machine learning
from sklearn.model_selection import train_test_split, GridSearchCV, PredefinedSplit
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier, plot_importance
import pickle

# Import libraries for model evaluation
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, make_scorer
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

pd.set_option('display.max_columns', None)

# %% [markdown]
# # A. DATA UNDERSTANDING AND PREPARATION

# %% [markdown]
# The dataset used was downloaded from this url: https://www.kaggle.com/competitions/playground-series-s3e3/data
#
# Dataset Description:
#
# The dataset for this competition (both train and test) was generated from a deep learning model trained on a Employee Attrition. Feature distributions are close to, but not exactly the same, as the original. Feel free to use the original dataset as part of this competition, both to explore differences as well as to see whether incorporating the original in training improves model performance.
#
# Some categorical variables were already label encoded. Here are the corresponding values:
#
# Education
# [1]'Below College'
# [2] 'College'
# [3] 'Bachelor'
# [4] 'Master'
# [5] 'Doctor'
#
# EnvironmentSatisfaction
# [1] 'Low'
# [2] 'Medium'
# [3] 'High'
# [4] 'Very High'
#
# JobInvolvement
# [1] 'Low'
# [2] 'Medium'
# [3] 'High'
# [4] 'Very High'
#
# JobSatisfaction
# [1] 'Low'
# [2] 'Medium'
# [3] 'High'
# [4] 'Very High'
#
# PerformanceRating
# [1] 'Low'
# [2] 'Good'
# [3] 'Excellent'
# [4] 'Outstanding'
#
# RelationshipSatisfaction
# [1] 'Low'
# [2] 'Medium'
# [3] 'High'
# [4] 'Very High'
#
# WorkLifeBalance
# [1] 'Bad'
# [2] 'Good'
# [3] 'Better'
# [4] 'Best'

# %%
train_path = r'C:\Users\MIllenium\Desktop\Personal\ML Projects\Dataset\playground-series-s3e3\attrition_train.csv'
test_path = r'C:\Users\MIllenium\Desktop\Personal\ML Projects\Dataset\playground-series-s3e3\attrition_test.csv'
orig_path = r'C:\Users\MIllenium\Desktop\Personal\ML Projects\Dataset\playground-series-s3e3\WA_Fn-UseC_-HR-Employee-Attrition.csv'

train = pd.read_csv(train_path)
test = pd.read_csv(test_path)
original = pd.read_csv(orig_path)

# %% [markdown]
# We will add the original dataset to have more samples for training the model.

# %%
# Display first 5 rows of the train dataset
train.head(5)
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4    Male          42               3         1
# 1                        1    Male          46               3         1
# 2                        3    Male          80               3         2
# 3                        3  Female          40               3         2
# 4                        2  Female          37               3         5
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                4       Married           2596
# 1       Sales Representative                1       Married           2899
# 2            Sales Executive                4      Divorced           4627
# 3  Healthcare Representative                1       Married           5347
# 4                    Manager                1        Single          19033
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0         5099                   1      Y      Yes                 13
# 1        10778                   1      Y       No                 17
# 2        16495                   0      Y       No                 17
# 3        13384                   3      Y       No                 14
# 4        19805                   1      Y      Yes                 13
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         2             80
# 1                  3                         4             80
# 2                  3                         4             80
# 3                  3                         3             80
# 4                  3                         3             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 1                 10                      2
# 1                 1                  4                      3
# 2                 2                  4                      3
# 3                 0                 15                      1
# 4                 0                 31                      0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
# 3                1               6                   0
# 4                3              31                  14
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0
# 3                        0                     2          0
# 4                        4                    10          1

# %%
# Display first 5 rows of the test dataset
test.head(5)
# Out:
#      id  Age     BusinessTravel  DailyRate              Department  \
# 0  1677   19         Non-Travel        992  Research & Development
# 1  1678   45      Travel_Rarely       1136                   Sales
# 2  1679   37      Travel_Rarely        155  Research & Development
# 3  1680   32      Travel_Rarely        688  Research & Development
# 4  1681   29  Travel_Frequently        464  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          1        Medical              1
# 1                 4          4      Marketing              1
# 2                13          3  Life Sciences              1
# 3                 1          4  Life Sciences              1
# 4                 9          1  Life Sciences              1
#
#    EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4   Male          43               3         1
# 1                        3   Male          67               3         2
# 2                        4   Male          41               3         1
# 3                        3   Male          89               2         2
# 4                        3   Male          79               3         1
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                3        Single           2318
# 1            Sales Executive                1      Divorced           5486
# 2         Research Scientist                4      Divorced           2741
# 3  Healthcare Representative                3        Single           5228
# 4      Laboratory Technician                4        Single           1223
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        17778                   1      Y       No                 12
# 1        12421                   6      Y      Yes                 12
# 2        23577                   4      Y      Yes                 13
# 3        20364                   1      Y       No                 13
# 4        15178                   1      Y       No                 14
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         4             80
# 1                  3                         3             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         1             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  1                      2
# 1                 1                  7                      3
# 2                 2                 13                      2
# 3                 0                 14                      2
# 4                 0                  1                      5
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                2               1                   0
# 1                3               2                   2
# 2                2               7                   7
# 3                2              14                  10
# 4                3               1                   0
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        2                     2
# 2                        1                     7
# 3                       11                     8
# 4                        0                     0

# %%
# Display first 5 rows of the original dataset
original.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %% [markdown]
# First we will format the original dataset similar to the competition dataset and merge the two dataset as the training dataset.

# %%
print('Duplicates from Original Dataset:', original.duplicated().sum())
print('Duplicates from Train Dataset:', train.duplicated().sum())
print('Duplicates from Test Dataset:', test.duplicated().sum())
# Out:
# Duplicates from Original Dataset: 0
# Duplicates from Train Dataset: 0
# Duplicates from Test Dataset: 0

# %% [markdown]
# There are no dupicates in each dataset.

# %%
# Drop the unique identifier in each dataset
df_train = train.drop('id', axis=1)
df_test = test.drop('id',axis=1)
df_original = original.drop('EmployeeNumber', axis=1)

# %%
# Format the original dataset to follow the column order of the competition dataset.
df_original = df_original[list(df_train.columns)]

# Create a new dataframe 'df_train_ext' that contains the train dataset and the original dataset
df_train_ext = pd.concat([df_train, df_original])

df_train_ext
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      36  Travel_Frequently        599  Research & Development
# 1      35      Travel_Rarely        921                   Sales
# 2      32      Travel_Rarely        718                   Sales
# 3      38      Travel_Rarely       1488  Research & Development
# 4      50      Travel_Rarely       1017  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                   24          3        Medical              1
# 1                    8          3          Other              1
# 2                   26          3      Marketing              1
# 3                    2          3        Medical              1
# 4                    5          4        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                           4    Male          42               3         1
# 1                           1    Male          46               3         1
# 2                           3    Male          80               3         2
# 3                           3  Female          40               3         2
# 4                           2  Female          37               3         5
# ...                       ...     ...         ...             ...       ...
# 1465                        3    Male          41               4         2
# 1466                        4    Male          42               2         3
# 1467                        2    Male          87               4         2
# 1468                        4    Male          63               2         2
# 1469                        2    Male          82               4         2
#
#                         JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0         Laboratory Technician                4       Married           2596
# 1          Sales Representative                1       Married           2899
# 2               Sales Executive                4      Divorced           4627
# 3     Healthcare Representative                1       Married           5347
# 4                       Manager                1        Single          19033
# ...                         ...              ...           ...            ...
# 1465      Laboratory Technician                4       Married           2571
# 1466  Healthcare Representative                1       Married           9991
# 1467     Manufacturing Director                2       Married           6142
# 1468            Sales Executive                2       Married           5390
# 1469      Laboratory Technician                3       Married           4404
#
#       MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0            5099                   1      Y      Yes                 13
# 1           10778                   1      Y       No                 17
# 2           16495                   0      Y       No                 17
# 3           13384                   3      Y       No                 14
# 4           19805                   1      Y      Yes                 13
# ...           ...                 ...    ...      ...                ...
# 1465        12290                   4      Y       No                 17
# 1466        21457                   4      Y       No                 15
# 1467         5174                   1      Y      Yes                 20
# 1468        13243                   2      Y       No                 14
# 1469        10228                   2      Y       No                 12
#
#       PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                     3                         2             80
# 1                     3                         4             80
# 2                     3                         4             80
# 3                     3                         3             80
# 4                     3                         3             80
# ...                 ...                       ...            ...
# 1465                  3                         3             80
# 1466                  3                         1             80
# 1467                  4                         2             80
# 1468                  3                         4             80
# 1469                  3                         1             80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    1                 10                      2
# 1                    1                  4                      3
# 2                    2                  4                      3
# 3                    0                 15                      1
# 4                    0                 31                      0
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                   3              10                   0
# 1                   3               4                   2
# 2                   3               3                   2
# 3                   1               6                   0
# 4                   3              31                  14
# ...               ...             ...                 ...
# 1465                3               5                   2
# 1466                3               7                   7
# 1467                3               6                   2
# 1468                2               9                   6
# 1469                4               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager Attrition
# 0                           7                     8         0
# 1                           0                     3         0
# 2                           1                     2         0
# 3                           0                     2         0
# 4                           4                    10         1
# ...                       ...                   ...       ...
# 1465                        0                     3        No
# 1466                        1                     7        No
# 1467                        0                     3        No
# 1468                        0                     8        No
# 1469                        1                     2        No
#
# [3147 rows x 34 columns]

# %%
# Replace the string values in the 'Attrition' column. 0 for 'No' and 1 for 'Yes'
df_train_ext['Attrition'] = df_train_ext['Attrition'].replace({'No':0, 'Yes':1})

# Check if the values in the 'Attrition' column are 0 and 1 only
df_train_ext['Attrition'].value_counts()
# Out:
# 0    2710
# 1     437
# Name: Attrition, dtype: int64

# %%
# Check if the combined rows of df_train and df_original is equal to the rows in df_train_ext
print('Sum of rows:', df_train.shape[0]+df_original.shape[0])
print('Total Rows in df_train_ext:', df_train_ext.shape[0])
# Out:
# Sum of rows: 3147
# Total Rows in df_train_ext: 3147

# %%
# Display the number of rows and the datatypes of each columns in the extended train dataset
df_train_ext.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3147 entries, 0 to 1469
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       3147 non-null   int64
#  1   BusinessTravel            3147 non-null   object
#  2   DailyRate                 3147 non-null   int64
#  3   Department                3147 non-null   object
#  4   DistanceFromHome          3147 non-null   int64
#  5   Education                 3147 non-null   int64
#  6   EducationField            3147 non-null   object
#  7   EmployeeCount             3147 non-null   int64
#  8   EnvironmentSatisfaction   3147 non-null   int64
#  9   Gender                    3147 non-null   object
#  10  HourlyRate                3147 non-null   int64
#  11  JobInvolvement            3147 non-null   int64
#  12  JobLevel                  3147 non-null   int64
#  13  JobRole                   3147 non-null   object
#  14  JobSatisfaction           3147 non-null   int64
#  15  MaritalStatus             3147 non-null   object
#  16  MonthlyIncome             3147 non-null   int64
#  17  MonthlyRate               3147 non-null   int64
#  18  NumCompaniesWorked        3147 non-null   int64
#  19  Over18                    3147 non-null   object
#  20  OverTime                  3147 non-null   object
#  21  PercentSalaryHike         3147 non-null   int64
#  22  PerformanceRating         3147 non-null   int64
#  23  RelationshipSatisfaction  3147 non-null   int64
#  24  StandardHours             3147 non-null   int64
#  25  StockOptionLevel          3147 non-null   int64
#  26  TotalWorkingYears         3147 non-null   int64
#  27  TrainingTimesLastYear     3147 non-null   int64
#  28  WorkLifeBalance           3147 non-null   int64
#  29  YearsAtCompany            3147 non-null   int64
#  30  YearsInCurrentRole        3147 non-null   int64
#  31  YearsSinceLastPromotion   3147 non-null   int64
#  32  YearsWithCurrManager      3147 non-null   int64
#  33  Attrition                 3147 non-null   int64
# dtypes: int64(26), object(8)
# memory usage: 860.5+ KB

# %% [markdown]
# The extended train dataset has 3,147 rows and 34 columns including the target variable. Based on the non-null count, there are no null values in the dataset. We will check the unique values in each categorical column if there are values such as 'None', 'N/A', 'Nan' or other values that may indicate that the value is null.

# %%
# Display the number of rows and the datatypes of each columns in the test dataset
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1119 non-null   int64
#  1   BusinessTravel            1119 non-null   object
#  2   DailyRate                 1119 non-null   int64
#  3   Department                1119 non-null   object
#  4   DistanceFromHome          1119 non-null   int64
#  5   Education                 1119 non-null   int64
#  6   EducationField            1119 non-null   object
#  7   EmployeeCount             1119 non-null   int64
#  8   EnvironmentSatisfaction   1119 non-null   int64
#  9   Gender                    1119 non-null   object
#  10  HourlyRate                1119 non-null   int64
#  11  JobInvolvement            1119 non-null   int64
#  12  JobLevel                  1119 non-null   int64
#  13  JobRole                   1119 non-null   object
#  14  JobSatisfaction           1119 non-null   int64
#  15  MaritalStatus             1119 non-null   object
#  16  MonthlyIncome             1119 non-null   int64
#  17  MonthlyRate               1119 non-null   int64
#  18  NumCompaniesWorked        1119 non-null   int64
#  19  Over18                    1119 non-null   object
#  20  OverTime                  1119 non-null   object
#  21  PercentSalaryHike         1119 non-null   int64
#  22  PerformanceRating         1119 non-null   int64
#  23  RelationshipSatisfaction  1119 non-null   int64
#  24  StandardHours             1119 non-null   int64
#  25  StockOptionLevel          1119 non-null   int64
#  26  TotalWorkingYears         1119 non-null   int64
#  27  TrainingTimesLastYear     1119 non-null   int64
#  28  WorkLifeBalance           1119 non-null   int64
#  29  YearsAtCompany            1119 non-null   int64
#  30  YearsInCurrentRole        1119 non-null   int64
#  31  YearsSinceLastPromotion   1119 non-null   int64
#  32  YearsWithCurrManager      1119 non-null   int64
# dtypes: int64(25), object(8)
# memory usage: 288.6+ KB

# %% [markdown]
# The test data set has 1,119 rows and 33 columns excluding the target variable. Based on the non-null count, there are no null values in the dataset. We will check the unique values in each categorical column if there are values such as 'None', 'N/A', 'Nan' or other values that may indicate that the value is null.

# %%
# Check the distribution of the target variable in the train dataset
ab = df_train_ext['Attrition'].value_counts()
sns.barplot(x=ab.index, y=ab.values)
for index, value in enumerate(ab.values):
    plt.text(index, value, f'{value:,}', ha='center', va='bottom', fontsize=9)
plt.title('Target Variable Distribution')
plt.show()

# %% [markdown]
# We have an unbalanced dataset. We will maintain this distribution in for now. We will decide later on if there is a need to balance this by oversampling or undersampling.

# %%
for i in df_train_ext.select_dtypes(include=['object']).columns.to_list():
    print(df_train_ext[i].value_counts())
    print('-'*50, '\n')
# Out:
# Travel_Rarely        2333
# Travel_Frequently     538
# Non-Travel            276
# Name: BusinessTravel, dtype: int64
# --------------------------------------------------
#
# Research & Development    2128
# Sales                      917
# Human Resources            102
# Name: Department, dtype: int64
# --------------------------------------------------
#
# Life Sciences       1381
# Medical             1013
# Marketing            311
# Technical Degree     238
# Other                164
# Human Resources       40
# Name: EducationField, dtype: int64
# --------------------------------------------------
#
# Male      1946
# Female    1201
# Name: Gender, dtype: int64
# --------------------------------------------------
#
# Sales Executive              681
# Research Scientist           636
# Laboratory Technician        593
# Manufacturing Director       341
# Healthcare Representative    286
# Manager                      213
# Sales Representative         160
# Research Director            151
# Human Resources               86
# Name: JobRole, dtype: int64
# --------------------------------------------------
#
# Married     1446
# Single      1047
# Divorced     654
# Name: MaritalStatus, dtype: int64
# --------------------------------------------------
#
# Y    3147
# Name: Over18, dtype: int64
# --------------------------------------------------
#
# No     2331
# Yes     816
# Name: OverTime, dtype: int64
# --------------------------------------------------

# %% [markdown]
# No values in the categorical variables are unusual or indicative of null value.

# %% [markdown]
# ## A1. Data Structuring

# %%
# Remove spaces in column names in the train dataset
df_train_ext.columns = df_train_ext.columns.str.replace(' ', '')
df_train_ext.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %% [markdown]
# This is to make sure that we call the approriate column names.

# %%
# Remove spaces in column names in the test dataset
df_test.columns = df_test.columns.str.replace(' ', '')
df_test.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## A1.1 Duplicates

# %%
# Check for duplicated rows in the train dataset
print('Train Dataset Duplicates', df_train_ext.duplicated().sum())

# Check for duplicated rows in the test dataset
print('Test Dataset Duplicates', df_test.duplicated().sum())
# Out:
# Train Dataset Duplicates 0
# Test Dataset Duplicates 0

# %% [markdown]
# ## A1.2 Outliers

# %% [markdown]
# Although the models that I will be using are robust against outliers, we will still check if there are outliers.

# %%
# Identify the categorical variables in the dataset
cat_var = df_train.select_dtypes(include=['object']).columns.to_list()

# Append the target varaibel 'Attrition' and any columns with only one unique value
single_value = []
for column in df_train.select_dtypes(exclude=['object']).columns:
    if len(df_train[column].unique()) == 1:
        single_value.append(column)
        
cat_var_ext = cat_var + single_value + ['Attrition']

# Visualize outliers for each variable in the train dataset
fig, ax = plt.subplots(nrows=6, ncols=4, figsize=(16, 9))

subplt = [[i, j] for i in range(6) for j in range(4)]


for i,col in enumerate(df_train.loc[:,~df_train.columns.isin(cat_var_ext)].columns):
    sns.boxplot(x=df_train[col], ax=ax[subplt[i][0],subplt[i][1]])
    #ax[subplt[i][0],subplt[i][1]].set_title('Plot {:}'.format(i+1))

plt.subplots_adjust(hspace=1)        
plt.show()

# %%
# Investigate outliers using statistical methods
ol_summ = pd.DataFrame(columns=['predictor', 'lower_limit', 'upper_limit', 'outlier_count'])

for col in df_train_ext.loc[:,~df_train_ext.columns.isin(cat_var_ext)].columns:
    # Compute the lower and upper limit
    q3 = df_train_ext[col].quantile(.75)
    q1 = df_train_ext[col].quantile(.25)
    lower_limit = q1 - ((q3 - q1) * 1.5)
    upper_limit = q3 + ((q3 - q1) * 1.5)
    
    # Count the number of outliers
    outliers = df_train_ext[(df_train_ext[col] < lower_limit) | (df_train_ext[col] > upper_limit)].shape[0]
    
    # Create a new row with the computed values
    row = pd.DataFrame([[col, lower_limit, upper_limit, outliers]], columns=['predictor', 'lower_limit',
                                                                             'upper_limit', 'outlier_count'])
    
    # Append the row to the 'ol_summ' DataFrame
    ol_summ = pd.concat([ol_summ, row], ignore_index=True)


ol_summ['count_percentage'] = ((ol_summ['outlier_count']/df_train_ext.shape[0])*100).astype('str').apply(lambda x: '{:.0f}%'.format(float(x)))
ol_summ[ol_summ['count_percentage'] != '0%'].sort_values('outlier_count', ascending=False).reset_index(drop=True)
# Out:
#                   predictor  lower_limit  upper_limit outlier_count  \
# 0     TrainingTimesLastYear          0.5          4.5           449
# 1         PerformanceRating          3.0          3.0           440
# 2   YearsSinceLastPromotion         -3.0          5.0           439
# 3             MonthlyIncome      -4367.5      14980.5           271
# 4            YearsAtCompany         -6.0         18.0           212
# 5          StockOptionLevel         -1.5          2.5           150
# 6        NumCompaniesWorked         -3.5          8.5           115
# 7         TotalWorkingYears         -7.5         28.5           110
# 8        YearsInCurrentRole         -5.5         14.5            42
# 9      YearsWithCurrManager         -5.5         14.5            30
# 10        PercentSalaryHike          4.5         24.5            28
#
#    count_percentage
# 0               14%
# 1               14%
# 2               14%
# 3                9%
# 4                7%
# 5                5%
# 6                4%
# 7                3%
# 8                1%
# 9                1%
# 10               1%

# %% [markdown]
# ## A2. Exploratory Data Analysis

# %%
# Summary Statistics
df_train_ext.describe().round(2)
# Out:
#            Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count  3147.00    3147.00           3147.00    3147.00         3147.0
# mean     36.45     850.59              8.92       2.93            1.0
# std       8.82     390.86              7.96       1.03            0.0
# min      18.00     102.00              1.00       1.00            1.0
# 25%      30.00     543.00              2.00       2.00            1.0
# 50%      35.00     852.00              7.00       3.00            1.0
# 75%      42.00    1198.50             13.00       4.00            1.0
# max      60.00    3921.00             29.00      15.00            1.0
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# count                  3147.00     3147.00         3147.00   3147.00
# mean                      2.74       66.91            2.76      2.03
# std                       1.09       19.88            0.68      1.09
# min                       1.00       30.00            1.00      1.00
# 25%                       2.00       50.00            2.00      1.00
# 50%                       3.00       67.00            3.00      2.00
# 75%                       4.00       84.00            3.00      3.00
# max                       4.00      100.00            4.00      7.00
#
#        JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# count          3147.00        3147.00      3147.00             3147.00
# mean              2.76        6339.40     14556.60                2.63
# std               1.10        4610.58      7117.33                2.49
# min               1.00        1009.00       636.00                0.00
# 25%               2.00        2888.00      8306.00                1.00
# 50%               3.00        4877.00     14908.00                1.00
# 75%               4.00        7725.00     20744.50                4.00
# max               4.00       19999.00     26999.00                9.00
#
#        PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# count            3147.00            3147.00                   3147.00
# mean               15.05               3.14                      2.73
# std                 3.54               0.35                      1.08
# min                11.00               3.00                      1.00
# 25%                12.00               3.00                      2.00
# 50%                14.00               3.00                      3.00
# 75%                17.00               3.00                      4.00
# max                25.00               4.00                      4.00
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         3147.0           3147.00            3147.00
# mean            80.0              0.76              10.98
# std              0.0              0.81               7.51
# min             80.0              0.00               0.00
# 25%             80.0              0.00               6.00
# 50%             80.0              1.00               9.00
# 75%             80.0              1.00              15.00
# max             80.0              3.00              41.00
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count                3147.00          3147.00          3147.0
# mean                    2.76             2.77             6.9
# std                     1.21             0.68             6.0
# min                     0.00             1.00             0.0
# 25%                     2.00             2.00             3.0
# 50%                     3.00             3.00             5.0
# 75%                     3.00             3.00             9.0
# max                     6.00             4.00            41.0
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# count             3147.00                  3147.00               3147.00
# mean                 4.18                     2.08                  4.16
# std                  3.60                     3.13                  3.57
# min                  0.00                     0.00                  0.00
# 25%                  2.00                     0.00                  2.00
# 50%                  3.00                     1.00                  3.00
# 75%                  7.00                     2.00                  7.00
# max                 18.00                    15.00                 17.00
#
#        Attrition
# count    3147.00
# mean        0.14
# std         0.35
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         1.00

# %%
# Display correlation between varaibles
plt.figure(figsize=(16, 10))

correlation = df_train_ext.loc[:,~df_train_ext.columns.isin(['BusinessTravel', 'Department', 'EducationField', 
                                                             'Gender', 'JobRole', 'MaritalStatus', 'OverTime', 
                                                             'EmployeeCount', 'Over18', 'StandardHours'])].corr().round(2)
sns.heatmap(correlation, vmin=-1, vmax=1, center=0 , annot=True)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# I observed high positive correlation between jobLevel and TotalWorkingYears. As expected, time-related variables are highly correlated with each other. Other than that, MonthlyIncome is also highly correlated with TotalWorkingYears and jobLevel. The higher the job role, the higher the Monthly Income.

# %%
# Visualize outliers for each variable in the train dataset
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(16, 25))

for i,col in enumerate(['BusinessTravel', 'Department', 'EducationField', 'Gender', 'MaritalStatus', 'JobRole']):
    subplt = ax[i // 2, i % 2]
    sns.countplot(df_train_ext, x=col, hue='Attrition', ax=subplt, order=df_train_ext[col].value_counts().index)
    subplt.set_title(f'Attrition: {col}')
    subplt.legend(title='Resigned', labels=['No', 'Yes'])
    subplt.set_ylabel('Employee Count')
    if col == 'JobRole':
        subplt.set_xticklabels(subplt.get_xticklabels(), rotation=45, ha='right', wrap=True)
    
plt.subplots_adjust(hspace=.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# Observations:
# 1. Majority of the employees travel rarely.
# <br>
#
# 2. The top 2 field of study of the employees are Life Sciences and Medical.
# <br>
#
# 3. Majority of the employees belong to the research & development department.
# <br>
#
# 4. Despite Life Sciences and Medical field as the dominant field of study by the employees, the top JobRole in the company belongs to Sales Executives. However, the top 2 and 3 job role belongs to Research Scientists and Laboratory Technician which are both connected to the medical field. In this case we could initially say that there is a significant portion of the employees who are career shifters from roles in the medical field to roles in sales.

# %%
plt.figure(figsize=(16,9))
sns.barplot(df_train_ext, x='JobLevel', y='MonthlyIncome', hue='Attrition', errorbar=None)
plt.title('Mean Monthly Income per Job Level')
plt.legend(title='Resigned', labels=['No', 'Yes'], loc='upper right')
plt.show()

# %%
df_train_ext[df_train_ext['JobRole'] == 'Manufacturing Director']
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 5      27      Travel_Rarely        566  Research & Development
# 11     29      Travel_Rarely        694  Research & Development
# 17     52      Travel_Rarely        607  Research & Development
# 19     25         Non-Travel       1092  Research & Development
# 25     29      Travel_Rarely       1005  Research & Development
# ...   ...                ...        ...                     ...
# 1418   38  Travel_Frequently        508  Research & Development
# 1440   36  Travel_Frequently        688  Research & Development
# 1445   41      Travel_Rarely        582  Research & Development
# 1463   31         Non-Travel        325  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 5                    2          3             Other              1
# 11                  28          3     Life Sciences              1
# 17                   2          4  Technical Degree              1
# 19                   1          1           Medical              1
# 25                   3          1     Life Sciences              1
# ...                ...        ...               ...            ...
# 1418                 6          4     Life Sciences              1
# 1440                 4          2     Life Sciences              1
# 1445                28          4     Life Sciences              1
# 1463                 5          3           Medical              1
# 1467                 4          3     Life Sciences              1
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 5                           3  Female          56               3         2
# 11                          3  Female          65               3         3
# 17                          2  Female          56               3         3
# 19                          4  Female          96               3         2
# 25                          2  Female          86               2         2
# ...                       ...     ...         ...             ...       ...
# 1418                        1    Male          72               2         2
# 1440                        4  Female          97               3         2
# 1445                        1  Female          60               2         4
# 1463                        2    Male          74               3         2
# 1467                        2    Male          87               4         2
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 5     Manufacturing Director                2        Single           4197
# 11    Manufacturing Director                3       Married           8628
# 17    Manufacturing Director                3        Single           7441
# 19    Manufacturing Director                4       Married           4374
# 25    Manufacturing Director                2        Single           4834
# ...                      ...              ...           ...            ...
# 1418  Manufacturing Director                3       Married           5321
# 1440  Manufacturing Director                2      Divorced           5131
# 1445  Manufacturing Director                2       Married          13570
# 1463  Manufacturing Director                1        Single           9936
# 1467  Manufacturing Director                2       Married           6142
#
#       MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 5            7103                   5      Y       No                 11
# 11          13939                   0      Y       No                 11
# 17          21143                   7      Y       No                 13
# 19          17000                   1      Y      Yes                 17
# 25           9129                   5      Y       No                 24
# ...           ...                 ...    ...      ...                ...
# 1418        14284                   2      Y       No                 11
# 1440         9192                   7      Y       No                 13
# 1445         5640                   0      Y       No                 23
# 1463         3787                   0      Y       No                 19
# 1467         5174                   1      Y      Yes                 20
#
#       PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 5                     3                         4             80
# 11                    3                         4             80
# 17                    3                         4             80
# 19                    3                         1             80
# 25                    4                         3             80
# ...                 ...                       ...            ...
# 1418                  3                         4             80
# 1440                  3                         2             80
# 1445                  4                         3             80
# 1463                  3                         2             80
# 1467                  4                         2             80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 5                    0                  6                      0
# 11                   0                 10                      2
# 17                   0                 28                      5
# 19                   0                  5                      3
# 25                   0                 10                      1
# ...                ...                ...                    ...
# 1418                 1                 10                      1
# 1440                 3                 18                      3
# 1445                 1                 21                      3
# 1463                 0                 10                      2
# 1467                 1                  6                      0
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 5                   3               1                   0
# 11                  3               9                   0
# 17                  1              10                   2
# 19                  4               5                   3
# 25                  2               1                   0
# ...               ...             ...                 ...
# 1418                3               8                   3
# 1440                3               4                   2
# 1445                3              20                   7
# 1463                3               9                   4
# 1467                3               6                   2
#
#       YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 5                           1                     0          0
# 11                          0                     7          0
# 17                          0                     8          0
# 19                          1                     4          0
# 25                          0                     0          0
# ...                       ...                   ...        ...
# 1418                        7                     7          0
# 1440                        0                     2          0
# 1445                        0                    10          0
# 1463                        1                     7          0
# 1467                        0                     3          0
#
# [341 rows x 34 columns]

# %%
df_train_ext[df_train_ext['JobLevel'] == 7]
# Out:
#       Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 1535   30  Travel_Rarely        583  Research & Development                 6
#
#       Education EducationField  EmployeeCount  EnvironmentSatisfaction  \
# 1535          3  Life Sciences              1                        4
#
#       Gender  HourlyRate  JobInvolvement  JobLevel                 JobRole  \
# 1535  Female         100               3         7  Manufacturing Director
#
#       JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 1535                3        Single           5326        22490
#
#       NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 1535                   3      Y       No                 13
#
#       PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 1535                  3                         4             80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1535                 0                 12                      1
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 1535                2               8                   7
#
#       YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 1535                        1                     5          0

# %% [markdown]
# This might be an encoding error or a case of underpaid employee. This employee is the only one with a job level of 7. The employee has a monthly income below the mean monthly income within the same job role.
#
# This is a fictional dataset which might be the reason why some of the values might not make sense. If we look closely the Monthly Income and Monthly Rate columns, we can see significant difference between the two. One reason could be that the employee has other sources of income which is why the monthly income is higher than the monthly rate. On the other hand, the employee might have other expenses which leads to a monthly income significantly lower than the monthly rate. These are just speculations about this part of the dataset which cannot be confirmed as it was not provided.
#
# For the purposes of this project, we will not dive deep on the relationship between the two variables.

# %%
plt.figure(figsize=(16,9))
sns.histplot(df_train_ext[df_train_ext['Attrition'] == 1], x='TotalWorkingYears', y='MonthlyIncome', color='tab:orange', 
             cbar=True)
plt.title('Monthly Income per Total Working Years of Resigned Employees')
plt.show()

# %% [markdown]
# Attrition is concentrated to those employees who have total working years of 0-10 years with monthly income below 5,000. There is low concentration on employees with high monthly rates between 17,500 to 20,000 and total years of experience between 20-40 years.

# %%
plt.figure(figsize=(16,9))
sns.histplot(df_train_ext[df_train_ext['Attrition'] == 1], x='NumCompaniesWorked', y='PercentSalaryHike', 
             color='tab:orange', cbar=True, bins=9)
plt.title('Salary Hike % per Number of Companies Worked of Resigned Employees')
plt.show()

# %% [markdown]
# Attrition has high concentration on employees who have worked for 1-2 companies during their career and have a salary hike of below 18%.

# %%
plt.figure(figsize=(16,9))
sns.histplot(df_train_ext[df_train_ext['Attrition'] == 1], x='DistanceFromHome', y='MonthlyRate', color='tab:orange', 
             cbar=True)
plt.title('Monthly Rate per Distance From Home of Resigned Employees')
plt.show()

# %%
sns.countplot(df_train_ext, x='StockOptionLevel', hue='Attrition', order=df_train_ext['StockOptionLevel'].value_counts().index)
plt.title('Attrition per Type of Stock Option')
plt.ylabel('Employee Count')
plt.xlabel('Type of Stock Option')
plt.legend(title='Resigned', labels=['No', 'Yes'], loc='upper right')
plt.show()

# %%
sns.countplot(df_train_ext, x='JobSatisfaction', hue='Attrition', order=df_train_ext['JobSatisfaction'].value_counts().index)
plt.title('Attrition per Job Satisfaction')
plt.ylabel('Employee Count')
plt.xlabel('Job Satisfaction Rating')
plt.legend(title='Resigned', labels=['No', 'Yes'], loc='upper right')
plt.show()

# %% [markdown]
# ## A3. Encoding Categorical Variables

# %%
# Display unique values in categorical columns in the train dataset
for i in cat_var:
    print(i, sorted(df_train_ext[i].unique()))
    print('-'*50)
# Out:
# BusinessTravel ['Non-Travel', 'Travel_Frequently', 'Travel_Rarely']
# --------------------------------------------------
# Department ['Human Resources', 'Research & Development', 'Sales']
# --------------------------------------------------
# EducationField ['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other', 'Technical Degree']
# --------------------------------------------------
# Gender ['Female', 'Male']
# --------------------------------------------------
# JobRole ['Healthcare Representative', 'Human Resources', 'Laboratory Technician', 'Manager', 'Manufacturing Director', 'Research Director', 'Research Scientist', 'Sales Executive', 'Sales Representative']
# --------------------------------------------------
# MaritalStatus ['Divorced', 'Married', 'Single']
# --------------------------------------------------
# Over18 ['Y']
# --------------------------------------------------
# OverTime ['No', 'Yes']
# --------------------------------------------------

# %%
# Label Encode the categorical variables in the extended train dataset
df_train_final = df_train_ext.copy()
for variable in cat_var:
    df_train_final[variable] = df_train_final[variable].astype('category').cat.codes
df_train_final
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      36               1        599           1                24          3
# 1      35               2        921           2                 8          3
# 2      32               2        718           2                26          3
# 3      38               2       1488           1                 2          3
# 4      50               2       1017           1                 5          4
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
#       EducationField  EmployeeCount  EnvironmentSatisfaction  Gender  \
# 0                  3              1                        4       1
# 1                  4              1                        1       1
# 2                  2              1                        3       1
# 3                  3              1                        3       0
# 4                  3              1                        2       0
# ...              ...            ...                      ...     ...
# 1465               3              1                        3       1
# 1466               3              1                        4       1
# 1467               1              1                        2       1
# 1468               3              1                        4       1
# 1469               3              1                        2       1
#
#       HourlyRate  JobInvolvement  JobLevel  JobRole  JobSatisfaction  \
# 0             42               3         1        2                4
# 1             46               3         1        8                1
# 2             80               3         2        7                4
# 3             40               3         2        0                1
# 4             37               3         5        3                1
# ...          ...             ...       ...      ...              ...
# 1465          41               4         2        2                4
# 1466          42               2         3        0                1
# 1467          87               4         2        4                2
# 1468          63               2         2        7                2
# 1469          82               4         2        2                3
#
#       MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  \
# 0                 1           2596         5099                   1       0
# 1                 1           2899        10778                   1       0
# 2                 0           4627        16495                   0       0
# 3                 1           5347        13384                   3       0
# 4                 2          19033        19805                   1       0
# ...             ...            ...          ...                 ...     ...
# 1465              1           2571        12290                   4       0
# 1466              1           9991        21457                   4       0
# 1467              1           6142         5174                   1       0
# 1468              1           5390        13243                   2       0
# 1469              1           4404        10228                   2       0
#
#       OverTime  PercentSalaryHike  PerformanceRating  \
# 0            1                 13                  3
# 1            0                 17                  3
# 2            0                 17                  3
# 3            0                 14                  3
# 4            1                 13                  3
# ...        ...                ...                ...
# 1465         0                 17                  3
# 1466         0                 15                  3
# 1467         1                 20                  4
# 1468         0                 14                  3
# 1469         0                 12                  3
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                            2             80                 1
# 1                            4             80                 1
# 2                            4             80                 2
# 3                            3             80                 0
# 4                            3             80                 0
# ...                        ...            ...               ...
# 1465                         3             80                 1
# 1466                         1             80                 1
# 1467                         2             80                 1
# 1468                         4             80                 0
# 1469                         1             80                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                    10                      2                3
# 1                     4                      3                3
# 2                     4                      3                3
# 3                    15                      1                1
# 4                    31                      0                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                 10                   0                        7
# 1                  4                   2                        0
# 2                  3                   2                        1
# 3                  6                   0                        0
# 4                 31                  14                        4
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager  Attrition
# 0                        8          0
# 1                        3          0
# 2                        2          0
# 3                        2          0
# 4                       10          1
# ...                    ...        ...
# 1465                     3          0
# 1466                     7          0
# 1467                     3          0
# 1468                     8          0
# 1469                     2          0
#
# [3147 rows x 34 columns]

# %%
# Label Encode the categorical variables in the test dataset
for variable in cat_var:
    df_test[variable] = df_test[variable].astype('category').cat.codes
df_test
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      19               0        992           1                 1          1
# 1      45               2       1136           2                 4          4
# 2      37               2        155           1                13          3
# 3      32               2        688           1                 1          4
# 4      29               1        464           1                 9          1
# ...   ...             ...        ...         ...               ...        ...
# 1114   31               2        755           2                 1          1
# 1115   40               2        654           1                26          5
# 1116   42               1        884           1                 1          4
# 1117   25               1       1469           2                 1          2
# 1118   42               2       1234           1                 2          4
#
#       EducationField  EmployeeCount  EnvironmentSatisfaction  Gender  \
# 0                  3              1                        4       1
# 1                  2              1                        3       1
# 2                  1              1                        4       1
# 3                  1              1                        3       1
# 4                  1              1                        3       1
# ...              ...            ...                      ...     ...
# 1114               1              1                        3       1
# 1115               3              1                        3       1
# 1116               3              1                        2       0
# 1117               5              1                        3       1
# 1118               1              1                        3       0
#
#       HourlyRate  JobInvolvement  JobLevel  JobRole  JobSatisfaction  \
# 0             43               3         1        2                3
# 1             67               3         2        7                1
# 2             41               3         1        6                4
# 3             89               2         2        0                3
# 4             79               3         1        2                4
# ...          ...             ...       ...      ...              ...
# 1114          81               2         1        8                4
# 1115          96               2         2        2                4
# 1116          65               3         2        0                1
# 1117          68               2         2        7                4
# 1118          95               3         4        3                4
#
#       MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  \
# 0                 2           2318        17778                   1       0
# 1                 0           5486        12421                   6       0
# 2                 0           2741        23577                   4       0
# 3                 2           5228        20364                   1       0
# 4                 2           1223        15178                   1       0
# ...             ...            ...          ...                 ...     ...
# 1114              0           4678         9150                   1       0
# 1115              1           6220         6409                   1       0
# 1116              1           5238         6069                   3       0
# 1117              1           4799        17519                   0       0
# 1118              1           1706        13953                   2       0
#
#       OverTime  PercentSalaryHike  PerformanceRating  \
# 0            0                 12                  3
# 1            1                 12                  3
# 2            1                 13                  3
# 3            0                 13                  3
# 4            0                 14                  3
# ...        ...                ...                ...
# 1114         0                 12                  3
# 1115         0                 14                  3
# 1116         0                 17                  3
# 1117         0                 11                  3
# 1118         0                 11                  3
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                            4             80                 0
# 1                            3             80                 1
# 2                            2             80                 2
# 3                            3             80                 0
# 4                            1             80                 0
# ...                        ...            ...               ...
# 1114                         3             80                 1
# 1115                         4             80                 1
# 1116                         1             80                 1
# 1117                         4             80                 1
# 1118                         3             80                 1
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     1                      2                2
# 1                     7                      3                3
# 2                    13                      2                2
# 3                    14                      2                2
# 4                     1                      5                3
# ...                 ...                    ...              ...
# 1114                  1                      1                3
# 1115                 20                      4                3
# 1116                 10                      2                2
# 1117                  5                      2                3
# 1118                 23                      2                3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  1                   0                        0
# 1                  2                   2                        2
# 2                  7                   7                        1
# 3                 14                  10                       11
# 4                  1                   0                        0
# ...              ...                 ...                      ...
# 1114               1                   0                        0
# 1115              20                  10                        1
# 1116               5                   3                        0
# 1117               4                   2                        1
# 1118              12                   7                        4
#
#       YearsWithCurrManager
# 0                        0
# 1                        2
# 2                        7
# 3                        8
# 4                        0
# ...                    ...
# 1114                     0
# 1115                     8
# 1116                     2
# 1117                     3
# 1118                     9
#
# [1119 rows x 33 columns]

# %% [markdown]
# ## A4. Feature Engineering

# %%
# Create a new feature called 'monthly_income_rate' by dividing the MonthlyIncome to the MonthyRate
df_train_final['monthly_income_rate'] = df_train_final['MonthlyIncome'] / df_train_final['MonthlyRate']
df_train_final.insert(df_train_final.columns.get_loc('MonthlyRate')+1, 'monthly_income_rate', df_train_final.pop('monthly_income_rate'))

# Create a new feature in the train dataset called 'salary_hike_per_hop' by diving the PercentSalaryHike to the NumCompaniesWorked
df_train_final['salary_hike_per_hop'] = round(df_train_final['PercentSalaryHike'] / df_train_final['NumCompaniesWorked'], 2)    
df_train_final.insert(df_train_final.columns.get_loc('PercentSalaryHike')+1, 'salary_hike_per_hop', df_train_final.pop('salary_hike_per_hop'))
df_train_final.loc[df_train_final['salary_hike_per_hop'] == np.inf, 'salary_hike_per_hop'] = 0

df_train_final
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      36               1        599           1                24          3
# 1      35               2        921           2                 8          3
# 2      32               2        718           2                26          3
# 3      38               2       1488           1                 2          3
# 4      50               2       1017           1                 5          4
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
#       EducationField  EmployeeCount  EnvironmentSatisfaction  Gender  \
# 0                  3              1                        4       1
# 1                  4              1                        1       1
# 2                  2              1                        3       1
# 3                  3              1                        3       0
# 4                  3              1                        2       0
# ...              ...            ...                      ...     ...
# 1465               3              1                        3       1
# 1466               3              1                        4       1
# 1467               1              1                        2       1
# 1468               3              1                        4       1
# 1469               3              1                        2       1
#
#       HourlyRate  JobInvolvement  JobLevel  JobRole  JobSatisfaction  \
# 0             42               3         1        2                4
# 1             46               3         1        8                1
# 2             80               3         2        7                4
# 3             40               3         2        0                1
# 4             37               3         5        3                1
# ...          ...             ...       ...      ...              ...
# 1465          41               4         2        2                4
# 1466          42               2         3        0                1
# 1467          87               4         2        4                2
# 1468          63               2         2        7                2
# 1469          82               4         2        2                3
#
#       MaritalStatus  MonthlyIncome  MonthlyRate  monthly_income_rate  \
# 0                 1           2596         5099             0.509119
# 1                 1           2899        10778             0.268974
# 2                 0           4627        16495             0.280509
# 3                 1           5347        13384             0.399507
# 4                 2          19033        19805             0.961020
# ...             ...            ...          ...                  ...
# 1465              1           2571        12290             0.209194
# 1466              1           9991        21457             0.465629
# 1467              1           6142         5174             1.187089
# 1468              1           5390        13243             0.407007
# 1469              1           4404        10228             0.430583
#
#       NumCompaniesWorked  Over18  OverTime  PercentSalaryHike  \
# 0                      1       0         1                 13
# 1                      1       0         0                 17
# 2                      0       0         0                 17
# 3                      3       0         0                 14
# 4                      1       0         1                 13
# ...                  ...     ...       ...                ...
# 1465                   4       0         0                 17
# 1466                   4       0         0                 15
# 1467                   1       0         1                 20
# 1468                   2       0         0                 14
# 1469                   2       0         0                 12
#
#       salary_hike_per_hop  PerformanceRating  RelationshipSatisfaction  \
# 0                   13.00                  3                         2
# 1                   17.00                  3                         4
# 2                    0.00                  3                         4
# 3                    4.67                  3                         3
# 4                   13.00                  3                         3
# ...                   ...                ...                       ...
# 1465                 4.25                  3                         3
# 1466                 3.75                  3                         1
# 1467                20.00                  4                         2
# 1468                 7.00                  3                         4
# 1469                 6.00                  3                         1
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0                80                 1                 10
# 1                80                 1                  4
# 2                80                 2                  4
# 3                80                 0                 15
# 4                80                 0                 31
# ...             ...               ...                ...
# 1465             80                 1                 17
# 1466             80                 1                  9
# 1467             80                 1                  6
# 1468             80                 0                 17
# 1469             80                 0                  6
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                         2                3              10
# 1                         3                3               4
# 2                         3                3               3
# 3                         1                1               6
# 4                         0                3              31
# ...                     ...              ...             ...
# 1465                      3                3               5
# 1466                      5                3               7
# 1467                      0                3               6
# 1468                      3                2               9
# 1469                      3                4               4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                      0                        7                     8
# 1                      2                        0                     3
# 2                      2                        1                     2
# 3                      0                        0                     2
# 4                     14                        4                    10
# ...                  ...                      ...                   ...
# 1465                   2                        0                     3
# 1466                   7                        1                     7
# 1467                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
#       Attrition
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1
# ...         ...
# 1465          0
# 1466          0
# 1467          0
# 1468          0
# 1469          0
#
# [3147 rows x 36 columns]

# %%
# Create a new feature in the test dataset called 'monthly_income_rate' by dividing the MonthlyIncome to the MonthyRate
df_test['monthly_income_rate'] = df_test['MonthlyIncome'] / df_test['MonthlyRate']
df_test.insert(df_test.columns.get_loc('MonthlyRate')+1, 'monthly_income_rate', df_test.pop('monthly_income_rate'))

# Create a new feature in the test dataset called 'salary_hike_per_hop' by diving the PercentSalaryHike to the NumCompaniesWorked
df_test['salary_hike_per_hop'] = round(df_test['PercentSalaryHike'] / df_test['NumCompaniesWorked'],2)
df_test.insert(df_test.columns.get_loc('PercentSalaryHike')+1, 'salary_hike_per_hop', df_test.pop('salary_hike_per_hop'))
df_test.loc[df_test['salary_hike_per_hop'] == np.inf, 'salary_hike_per_hop'] = 0

df_test
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      19               0        992           1                 1          1
# 1      45               2       1136           2                 4          4
# 2      37               2        155           1                13          3
# 3      32               2        688           1                 1          4
# 4      29               1        464           1                 9          1
# ...   ...             ...        ...         ...               ...        ...
# 1114   31               2        755           2                 1          1
# 1115   40               2        654           1                26          5
# 1116   42               1        884           1                 1          4
# 1117   25               1       1469           2                 1          2
# 1118   42               2       1234           1                 2          4
#
#       EducationField  EmployeeCount  EnvironmentSatisfaction  Gender  \
# 0                  3              1                        4       1
# 1                  2              1                        3       1
# 2                  1              1                        4       1
# 3                  1              1                        3       1
# 4                  1              1                        3       1
# ...              ...            ...                      ...     ...
# 1114               1              1                        3       1
# 1115               3              1                        3       1
# 1116               3              1                        2       0
# 1117               5              1                        3       1
# 1118               1              1                        3       0
#
#       HourlyRate  JobInvolvement  JobLevel  JobRole  JobSatisfaction  \
# 0             43               3         1        2                3
# 1             67               3         2        7                1
# 2             41               3         1        6                4
# 3             89               2         2        0                3
# 4             79               3         1        2                4
# ...          ...             ...       ...      ...              ...
# 1114          81               2         1        8                4
# 1115          96               2         2        2                4
# 1116          65               3         2        0                1
# 1117          68               2         2        7                4
# 1118          95               3         4        3                4
#
#       MaritalStatus  MonthlyIncome  MonthlyRate  monthly_income_rate  \
# 0                 2           2318        17778             0.130386
# 1                 0           5486        12421             0.441671
# 2                 0           2741        23577             0.116257
# 3                 2           5228        20364             0.256728
# 4                 2           1223        15178             0.080577
# ...             ...            ...          ...                  ...
# 1114              0           4678         9150             0.511257
# 1115              1           6220         6409             0.970510
# 1116              1           5238         6069             0.863075
# 1117              1           4799        17519             0.273931
# 1118              1           1706        13953             0.122268
#
#       NumCompaniesWorked  Over18  OverTime  PercentSalaryHike  \
# 0                      1       0         0                 12
# 1                      6       0         1                 12
# 2                      4       0         1                 13
# 3                      1       0         0                 13
# 4                      1       0         0                 14
# ...                  ...     ...       ...                ...
# 1114                   1       0         0                 12
# 1115                   1       0         0                 14
# 1116                   3       0         0                 17
# 1117                   0       0         0                 11
# 1118                   2       0         0                 11
#
#       salary_hike_per_hop  PerformanceRating  RelationshipSatisfaction  \
# 0                   12.00                  3                         4
# 1                    2.00                  3                         3
# 2                    3.25                  3                         2
# 3                   13.00                  3                         3
# 4                   14.00                  3                         1
# ...                   ...                ...                       ...
# 1114                12.00                  3                         3
# 1115                14.00                  3                         4
# 1116                 5.67                  3                         1
# 1117                 0.00                  3                         4
# 1118                 5.50                  3                         3
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0                80                 0                  1
# 1                80                 1                  7
# 2                80                 2                 13
# 3                80                 0                 14
# 4                80                 0                  1
# ...             ...               ...                ...
# 1114             80                 1                  1
# 1115             80                 1                 20
# 1116             80                 1                 10
# 1117             80                 1                  5
# 1118             80                 1                 23
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                         2                2               1
# 1                         3                3               2
# 2                         2                2               7
# 3                         2                2              14
# 4                         5                3               1
# ...                     ...              ...             ...
# 1114                      1                3               1
# 1115                      4                3              20
# 1116                      2                2               5
# 1117                      2                3               4
# 1118                      2                3              12
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                      0                        0                     0
# 1                      2                        2                     2
# 2                      7                        1                     7
# 3                     10                       11                     8
# 4                      0                        0                     0
# ...                  ...                      ...                   ...
# 1114                   0                        0                     0
# 1115                  10                        1                     8
# 1116                   3                        0                     2
# 1117                   2                        1                     3
# 1118                   7                        4                     9
#
# [1119 rows x 35 columns]

# %% [markdown]
# ## A4.1 Feature Selection

# %% [markdown]
# Earlier, you can observe that there was a class imbalance in the distribution of the target variable. To address this, I used SMOTE or Synthetic Minority Over-sampling Technique where the algorithm generates synthetic samples for the minority class by interpolating between existing minority class instances.

# %%
# Identify the predictor variables
X = df_train_final.drop(columns=['Attrition', 'EmployeeCount', 'Over18', 'StandardHours'])
y = df_train_final['Attrition']

X_new = df_test.drop(columns=['EmployeeCount', 'Over18', 'StandardHours'])

# Test the dataset into training, testing, and validation sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=42)
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.20, random_state=42)

# Create a custom validation set
split_indices = [0 if x in X_val.index else -1 for x in X_train.index]
custom_split = PredefinedSplit(split_indices)

# %%
# Check the shape of the train, test, and validation sets
print('Original X shape:', X.shape)
print('Original y shape:', y.shape)
print('Predictor Variables Training Set shape:', X_train.shape)
print('Target Variable Training Set shape:', y_train.shape)
print('Predictor Variables Testing Set shape:', X_test.shape)
print('Target Variable Testing Set shape:', y_test.shape)
print('Predictor Variables Validation Set shape:', X_val.shape)
print('Target Variable Validation Set shape:', y_val.shape)
# Out:
# Original X shape: (3147, 32)
# Original y shape: (3147,)
# Predictor Variables Training Set shape: (2360, 32)
# Target Variable Training Set shape: (2360,)
# Predictor Variables Testing Set shape: (787, 32)
# Target Variable Testing Set shape: (787,)
# Predictor Variables Validation Set shape: (472, 32)
# Target Variable Validation Set shape: (472,)

# %% [markdown]
# # B. MODELING

# %%
# Create a function to tabulate the cross validation metrics

def cv_results(model_name, model_object, metric, summary):
    '''
    Arguments:
        model_name (string): what you want the model to be called in the output table
        model_object: a fit machine learning model object
        metric (string): precision, recall, f1, or accuracy

    Returns a pandas df with the F1, recall, precision, and accuracy scores
    for the model with the best mean 'metric' score across all validation folds.
    '''
    # Create dictionary that maps input metric to actual metric name in GridSearchCV
    metric_dict = {'accuracy': 'mean_test_accuracy',
                   'precision': 'mean_test_precision',
                   'recall': 'mean_test_recall',
                   'f1': 'mean_test_f1',
                   'auc': 'mean_test_roc_auc'}
    
    # Get all the results from the CV and put them in a df
    cv_results_df = pd.DataFrame(model_object.cv_results_)
    
    # Isolate the row of the df with the max(metric) score
    best_estimator_results = cv_results_df.iloc[cv_results_df[metric_dict[metric]].idxmax(), :]
    
    # Extract Accuracy, precision, recall, and f1 score from that row
    accuracy = (best_estimator_results.mean_test_accuracy*100).round(2).astype(str)
    precision = (best_estimator_results.mean_test_precision*100).round(2).astype(str)
    recall = (best_estimator_results.mean_test_recall*100).round(2).astype(str)
    f1 = (best_estimator_results.mean_test_f1*100).round(2).astype(str)
    auc = best_estimator_results.mean_test_roc_auc.round(2).astype(str)
    
    # Create table of results
    model_score = pd.DataFrame([[model_name, '{0}%'.format(accuracy), '{0}%'.format(precision), '{0}%'.format(recall), '{0}%'.format(f1), auc]], columns=['model', 'accuracy', 'precision', 'recall', 'f1_score', 'roc_auc_score'])
    summary = pd.concat([summary, model_score], ignore_index=True)

    return summary


# Create a function to tabulate the prediction metrics

def test_result(model_name, preds, y_test_data, summary):
    '''
    Generate a table of test scores.

    In:
        model_name (string): Your choice: how the model will be named in the output table
        preds: numpy array of test predictions
        y_test_data: numpy array of y_test data

    Out:
        table: a pandas df of precision, recall, f1, and accuracy scores for your model
    '''
    # Extract Accuracy, precision, recall, and f1 score of the prediction
    accuracy = (accuracy_score(y_test_data, preds)*100).round(2).astype(str)
    precision = (precision_score(y_test_data, preds)*100).round(2).astype(str)
    recall = (recall_score(y_test_data, preds)*100).round(2).astype(str)
    f1 = (f1_score(y_test_data, preds)*100).round(2).astype(str)
    auc = roc_auc_score(y_test_data, preds).round(2).astype(str)
    
    # Create table of results
    model_score = pd.DataFrame([[model_name, '{0}%'.format(accuracy), '{0}%'.format(precision), '{0}%'.format(recall), '{0}%'.format(f1), auc]], columns=['model', 'accuracy', 'precision', 'recall', 'f1_score', 'roc_auc_score'])
    summary = pd.concat([summary, model_score], ignore_index=True)

    return summary

# %%
# Create a blank dataframe for the summary of the metrics
summ_results = pd.DataFrame(columns=['model', 'accuracy', 'precision', 'recall', 'f1_score', 'roc_auc_score'])

# %%
# Create a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# %% [markdown]
# ## B1. Naive Bayes Model

# %%
# Instantiate the model
gnb = GaussianNB()

# Fit the model
gnb.fit(X_train, y_train)

# Make predictions on the testing set
gnb_preds = gnb.predict(X_test)

# %% [markdown]
# ## B1.1 Model Evaluation

# %%
# Display the prediction metrics
summ_results = test_result('Naive Bayes (Testing Set Prediction)', gnb_preds, y_test, summ_results)
summ_results
# Out:
#                                   model accuracy precision  recall f1_score  \
# 0  Naive Bayes (Testing Set Prediction)   81.07%     37.8%  56.88%   45.42%
#
#   roc_auc_score
# 0          0.71

# %%
# Display the results in a confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, gnb_preds)
plt.xticks(ticks=gnb.classes_, labels=['Stayed', 'Resigned'])
plt.yticks(ticks=gnb.classes_, labels=['Stayed', 'Resigned'])
plt.show()

# %% [markdown]
# ## B2. Decision Tree

# %%
# %%time
# Instantiate the model
dt = DecisionTreeClassifier(random_state=0)

# Fit the model
dt.fit(X_train, y_train)

# Make predictions on the testing set
dt_preds = dt.predict(X_test)
# Out:
# CPU times: total: 93.8 ms
# Wall time: 88.3 ms

# %% [markdown]
# ## B2.1 Model Evaluation

# %%
# Display the prediction metrics
summ_results = test_result('Decision Tree - Base Model (Testing Set Prediction)', dt_preds, y_test, summ_results)
summ_results
# Out:
#                                                model accuracy precision  \
# 0               Naive Bayes (Testing Set Prediction)   81.07%     37.8%
# 1  Decision Tree - Base Model (Testing Set Predic...   79.54%     30.0%
#
#    recall f1_score roc_auc_score
# 0  56.88%   45.42%          0.71
# 1  35.78%   32.64%          0.61

# %%
# Display the results in a confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, dt_preds, values_format='d')
plt.xticks(ticks=dt.classes_, labels=['Stayed', 'Resigned'])
plt.yticks(ticks=dt.classes_, labels=['Stayed', 'Resigned'])
plt.show()

# %%
# Plot the tree
plt.figure(figsize=(16,9))
plot_tree(dt, max_depth=2, fontsize=14, feature_names=X_train.columns, 
          class_names={0:'Not Resign', 1:'Resign'}, filled=True);
plt.show()

# %%
# Display feature importance
importances = dt.feature_importances_
forest_importances = pd.Series(importances, index=X_train.columns).sort_values(ascending=False)
fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
plt.show()

# %% [markdown]
# The decision tree gives greater importance to the variable MonthlyIncome, MonthlyRate, and TotalWorkingYears in making the predictions.

# %% [markdown]
# ## B2.2 Hyperparameter Tuning

# %%
# %%time
#Create a dictionary for the max_depth and min_samples_leaf hyperparameter
hyperpara = {'max_depth':[15, 25, 50, None],
             'min_samples_leaf': [2, 3, 4, 5, 8]}

#Instantiate the decision tree classifier
dt_tuned = DecisionTreeClassifier(random_state = 0)

# Instantiate the GridSearch
dt_gscv = GridSearchCV(dt_tuned, hyperpara, scoring = scoring, cv=custom_split, refit="f1", n_jobs=-1, verbose=2)

# Fit the model
dt_gscv.fit(X_train, y_train)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# CPU times: total: 234 ms
# Wall time: 4.94 s
# GridSearchCV(cv=PredefinedSplit(test_fold=array([ 0, -1, ..., -1, -1])),
#              estimator=DecisionTreeClassifier(random_state=0), n_jobs=-1,
#              param_grid={'max_depth': [15, 25, 50, None],
#                          'min_samples_leaf': [2, 3, 4, 5, 8]},
#              refit='f1',
#              scoring={'accuracy', 'precision', 'roc_auc', 'f1', 'recall'},
#              verbose=2)

# %% [markdown]
# ## B2.2a Model Evaluation

# %%
# Examine the best model from GridSearch
dt_gscv.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=15, min_samples_leaf=2, random_state=0)

# %%
# Displya the best validation score for the selected metric
print("Best Avg. Validation Score: ", "%.4f" % dt_gscv.best_score_)
# Out:
# Best Avg. Validation Score:  0.3216

# %%
# Display the cross validation metrics
summ_results = cv_results('Decision Tree - Tuned (Cross-Validation)', dt_gscv, 'f1', summ_results)

# Make predictions on the testing set
dt_gscv_preds = dt_gscv.best_estimator_.predict(X_test)

# Display the prediction metrics
summ_results = test_result('Decision Tree - Tuned (Testing Set Prediction)', dt_gscv_preds, y_test, summ_results)

summ_results
# Out:
#                                                model accuracy precision  \
# 0               Naive Bayes (Testing Set Prediction)   81.07%     37.8%
# 1  Decision Tree - Base Model (Testing Set Predic...   79.54%     30.0%
# 2           Decision Tree - Tuned (Cross-Validation)   81.53%    35.56%
# 3     Decision Tree - Tuned (Testing Set Prediction)   81.96%    31.46%
#
#    recall f1_score roc_auc_score
# 0  56.88%   45.42%          0.71
# 1  35.78%   32.64%          0.61
# 2  29.36%   32.16%           0.6
# 3  25.69%   28.28%          0.58

# %%
# Display the results in a confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, dt_gscv_preds, values_format='d')
plt.xticks(ticks=dt_gscv.classes_, labels=['Stayed', 'Resigned'])
plt.yticks(ticks=dt_gscv.classes_, labels=['Stayed', 'Resigned'])
plt.show()

# %%
# Plot the tree
plt.figure(figsize=(16,9))
plot_tree(dt_gscv.best_estimator_, max_depth=2, fontsize=14, feature_names=X_train.columns, 
          class_names={0:'Not Resign', 1:'Resign'}, filled=True);
plt.show()

# %%
# Display feature importance
importances = dt_gscv.best_estimator_.feature_importances_
forest_importances = pd.Series(importances, index=X_train.columns).sort_values(ascending=False)
fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
plt.show()

# %% [markdown]
# ## B3. Random Forest

# %%
# %%time
# Instantiate the model
rf = RandomForestClassifier(random_state=0)

# Create a disctionary of parameters
hyperpara = {'max_depth': [8, 10, 15],
             'min_samples_leaf': [3, 4],
             'min_samples_split': [5, 10],
             'max_features': [8, 16, 24],
             'n_estimators': [100]}

# Use GridSearchCV to find the best parameters
rf_gscv = GridSearchCV(rf, hyperpara, scoring=scoring, refit = 'f1', cv = custom_split, n_jobs=-1, verbose=2)

# Fit the model
rf_gscv.fit(X_train, y_train)
# Out:
# Fitting 1 folds for each of 36 candidates, totalling 36 fits
# CPU times: total: 1.91 s
# Wall time: 29.7 s
# GridSearchCV(cv=PredefinedSplit(test_fold=array([ 0, -1, ..., -1, -1])),
#              estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'max_depth': [8, 10, 15], 'max_features': [8, 16, 24],
#                          'min_samples_leaf': [3, 4],
#                          'min_samples_split': [5, 10], 'n_estimators': [100]},
#              refit='f1',
#              scoring={'accuracy', 'precision', 'roc_auc', 'f1', 'recall'},
#              verbose=2)

# %% [markdown]
# ## B3.1 Model Evaluation

# %%
# Examine the best model from GridSearch
rf_gscv.best_estimator_
# Out:
# RandomForestClassifier(max_depth=15, max_features=16, min_samples_leaf=3,
#                        min_samples_split=10, random_state=0)

# %%
# Display the parameters of the best estimator
rf_gscv.best_params_
# Out:
# {'max_depth': 15,
#  'max_features': 16,
#  'min_samples_leaf': 3,
#  'min_samples_split': 10,
#  'n_estimators': 100}

# %%
# Display the cross validation metrics
summ_results = cv_results('Random Forest (Cross-Validation)', rf_gscv, 'f1', summ_results)

# Make predictions on the testing set
rf_gscv_preds = rf_gscv.best_estimator_.predict(X_test)

# Display the prediction metrics
summ_results = test_result('Random Forest (Testing Set Prediction)', rf_gscv_preds, y_test, summ_results)

summ_results
# Out:
#                                                model accuracy precision  \
# 0               Naive Bayes (Testing Set Prediction)   81.07%     37.8%
# 1  Decision Tree - Base Model (Testing Set Predic...   79.54%     30.0%
# 2           Decision Tree - Tuned (Cross-Validation)   81.53%    35.56%
# 3     Decision Tree - Tuned (Testing Set Prediction)   81.96%    31.46%
# 4                   Random Forest (Cross-Validation)    87.0%    73.33%
# 5             Random Forest (Testing Set Prediction)   87.55%    73.91%
#
#    recall f1_score roc_auc_score
# 0  56.88%   45.42%          0.71
# 1  35.78%   32.64%          0.61
# 2  29.36%   32.16%           0.6
# 3  25.69%   28.28%          0.58
# 4  20.18%   31.65%           0.8
# 5   15.6%   25.76%          0.57

# %%
# Display the results in a confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, rf_gscv_preds, values_format='d')
plt.xticks(ticks=rf_gscv.classes_, labels=['Stayed', 'Resigned'])
plt.yticks(ticks=rf_gscv.classes_, labels=['Stayed', 'Resigned'])
plt.show()

# %%
# Plot the tree
fig, ax = plt.subplots(nrows=5, ncols=1, figsize=(16, 40))

for i in range(5):
    plot_tree(rf_gscv.best_estimator_.estimators_[i], max_depth=2, fontsize=11, feature_names=X_train.columns, 
              class_names={0:'Not Resign', 1:'Resign'}, filled=True, ax=ax[i])
    ax[i].set_title('Ensemble {}'.format(i))
plt.show()

# %%
# Display feature importance
importances = rf_gscv.best_estimator_.feature_importances_
forest_importances = pd.Series(importances, index=X_train.columns).sort_values(ascending=False)
fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
plt.show()

# %% [markdown]
# ## B4. XGBoost

# %%
# %%time
# Instantiate the model
xgb = XGBClassifier(objective='binary:logistic', random_state=0)

# Create a disctionary of parameters
hyperpara = {'max_depth': [8, 10, 20],
             'min_child_weight': [8, 10],
             'learning_rate': [.3, .2, .1],
             'n_estimators': [100],
             'colsample_bytree': [.9, .8, .7]}

# Use GridSearchCV to find the best parameters
xgb_gscv = GridSearchCV(xgb, hyperpara, scoring=scoring, refit = 'f1', cv = custom_split, n_jobs=-1, verbose=2)

# Fit the model
xgb_gscv.fit(X_train, y_train)
# Out:
# Fitting 1 folds for each of 54 candidates, totalling 54 fits
# CPU times: total: 2.92 s
# Wall time: 19.3 s
# GridSearchCV(cv=PredefinedSplit(test_fold=array([ 0, -1, ..., -1, -1])),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None...
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=0, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.9, 0.8, 0.7],
#                          'learning_rate': [0.3, 0.2, 0.1],
#                          'max_depth': [8, 10, 20], 'min_child_weight': [8, 10],
#                          'n_estimators': [100]},
#              refit='f1',
#              scoring={'accuracy', 'precision', 'roc_auc', 'f1', 'recall'},
#              verbose=2)

# %% [markdown]
# ## B4.1 Model Evaluation

# %%
# Examine the best model from GridSearch
xgb_gscv.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=10, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=0, ...)

# %%
# Display the parameters of the best estimator
xgb_gscv.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'learning_rate': 0.1,
#  'max_depth': 10,
#  'min_child_weight': 10,
#  'n_estimators': 100}

# %%
# Display the cross validation metrics
summ_results = cv_results('XGBoost (Cross-Validation)', xgb_gscv, 'f1', summ_results)

# Make predictions on the testing set
xgb_gscv_preds = xgb_gscv.best_estimator_.predict(X_test)

# Display the prediction metrics
summ_results = test_result('XGBoost (Testing Set Prediction)', xgb_gscv_preds, y_test, summ_results)

summ_results
# Out:
#                                                model accuracy precision  \
# 0               Naive Bayes (Testing Set Prediction)   81.07%     37.8%
# 1  Decision Tree - Base Model (Testing Set Predic...   79.54%     30.0%
# 2           Decision Tree - Tuned (Cross-Validation)   81.53%    35.56%
# 3     Decision Tree - Tuned (Testing Set Prediction)   81.96%    31.46%
# 4                   Random Forest (Cross-Validation)    87.0%    73.33%
# 5             Random Forest (Testing Set Prediction)   87.55%    73.91%
# 6                         XGBoost (Cross-Validation)   87.28%    67.39%
# 7                   XGBoost (Testing Set Prediction)   88.44%     72.5%
#
#    recall f1_score roc_auc_score
# 0  56.88%   45.42%          0.71
# 1  35.78%   32.64%          0.61
# 2  29.36%   32.16%           0.6
# 3  25.69%   28.28%          0.58
# 4  20.18%   31.65%           0.8
# 5   15.6%   25.76%          0.57
# 6  28.44%    40.0%          0.83
# 7  26.61%   38.93%          0.62

# %%
# Display the results in a confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, xgb_gscv_preds, values_format='d')
plt.xticks(ticks=xgb_gscv.classes_, labels=['Stayed', 'Resigned'])
plt.yticks(ticks=xgb_gscv.classes_, labels=['Stayed', 'Resigned'])
plt.show()

# %%
# Display feature importance
importances = xgb_gscv.best_estimator_.feature_importances_
forest_importances = pd.Series(importances, index=X_train.columns).sort_values(ascending=False)
fig, ax = plt.subplots()
forest_importances.plot.bar(ax=ax)
plt.show()

# %% [markdown]
# ## B5. Model Selection

# %%
best_model = summ_results[summ_results['model'].str.contains('(Testing Set Prediction)', regex=False)]
best_model[best_model['f1_score'] == best_model['f1_score'].max()]
# Out:
#                                   model accuracy precision  recall f1_score  \
# 0  Naive Bayes (Testing Set Prediction)   81.07%     37.8%  56.88%   45.42%
#
#   roc_auc_score
# 0          0.71

# %% [markdown]
# # C. OVERSAMPLING EXPERIMENT

# %%
# Initialize SMOTE
smote = SMOTE(sampling_strategy='minority', random_state=42)

# Apply SMOTE to create a balanced dataset
X_resampled, y_resampled = smote.fit_resample(X, y)

# Test the dataset into training, testing, and validation sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.25, random_state=42)
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.20, random_state=42)

# %%
# Check the distribution of the target variable
ab = y_resampled.value_counts()
sns.barplot(x=ab.index, y=ab.values)
for index, value in enumerate(ab.values):
    plt.text(index, value, f'{value:,}', ha='center', va='bottom', fontsize=9)
plt.title('Target Variable Distribution After SMOTE')
plt.show()

# %%
# Check the shape of the train, test, and validation sets
print('Original X shape:', X.shape)
print('Original y shape:', y.shape)
print('Resampled X shape:', X_resampled.shape)
print('Resampled y shape:', y_resampled.shape)
print('Predictor Variables Training Set shape:', X_train.shape)
print('Target Variable Training Set shape:', y_train.shape)
print('Predictor Variables Testing Set shape:', X_test.shape)
print('Target Variable Testing Set shape:', y_test.shape)
print('Predictor Variables Validation Set shape:', X_val.shape)
print('Target Variable Validation Set shape:', y_val.shape)
# Out:
# Original X shape: (3147, 32)
# Original y shape: (3147,)
# Resampled X shape: (5420, 32)
# Resampled y shape: (5420,)
# Predictor Variables Training Set shape: (4065, 32)
# Target Variable Training Set shape: (4065,)
# Predictor Variables Testing Set shape: (1355, 32)
# Target Variable Testing Set shape: (1355,)
# Predictor Variables Validation Set shape: (813, 32)
# Target Variable Validation Set shape: (813,)

# %%
# Create a function to fit and evaluate all models in the dictionary 'models'
def model_eval(X_train, y_train, X_test, y_test, metric):
    # Instantiate the models
    gnb = GaussianNB()
    dt = DecisionTreeClassifier(random_state=0)
    dt_tuned = DecisionTreeClassifier(random_state = 0)
    rf = RandomForestClassifier(random_state=0)
    xgb = XGBClassifier(objective='binary:logistic', random_state=0)

    # Dictionary of models
    models = {'Naive Bayes': gnb, 'Decision Tree - Base Model': dt,
              'Decision Tree - Tuned': dt_tuned, 'Random Forest': rf, 'XGBoost': xgb}

    #Create a dictionary for the max_depth and min_samples_leaf hyperparameter
    hyperpara = {'Decision Tree - Tuned': {'max_depth':[15, 25, 50, None], 'min_samples_leaf': [2, 3, 4, 5, 8]},
                 'Random Forest': {'max_depth': [8, 10, 15], 'min_samples_leaf': [3, 4], 'min_samples_split': [5, 10], 'max_features': [8, 16, 24], 'n_estimators': [100]},
                 'XGBoost': {'max_depth': [8, 10, 20], 'min_child_weight': [8, 10], 'learning_rate': [.3, .2, .1], 'n_estimators': [100], 'colsample_bytree': [.9, .8, .7]}
                 }
    
    # Create a blank dataframe for the summary of the metrics
    summ_results = pd.DataFrame(columns=['model', 'accuracy', 'precision', 'recall', 'f1_score', 'roc_auc_score'])
    
    for key,value in models.items():
        if key in ['Decision Tree - Tuned', 'Random Forest', 'XGBoost']:
            # Instantiate the GridSearch
            gscv = GridSearchCV(models[key], hyperpara[key], scoring = scoring, cv=custom_split, refit=metric, n_jobs=-1, verbose=2)

            # Fit the model
            gscv.fit(X_train, y_train)
            
            # Display the cross validation metrics
            summ_results = cv_results(f'{key} (Cross-Validation)', gscv, metric, summ_results)
            
            # Make predictions on the testing set
            pred = gscv.best_estimator_.predict(X_test)
            
        else:          
            # Fit the model
            value.fit(X_train, y_train)
            
            # Make predictions on the testing set
            pred = value.predict(X_test)
        
        # Display the prediction metrics
        summ_results = test_result(f'{key} (Testing Set Prediction)', pred, y_test, summ_results)
        
    return summ_results



model_eval(X_train, y_train, X_test, y_test, 'f1')
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# Fitting 1 folds for each of 36 candidates, totalling 36 fits
# Fitting 1 folds for each of 54 candidates, totalling 54 fits
#                                                model accuracy precision  \
# 0               Naive Bayes (Testing Set Prediction)    72.1%    68.42%
# 1  Decision Tree - Base Model (Testing Set Predic...   82.73%    80.57%
# 2           Decision Tree - Tuned (Cross-Validation)   80.71%    84.18%
# 3     Decision Tree - Tuned (Testing Set Prediction)   82.51%    83.23%
# 4                   Random Forest (Cross-Validation)   87.55%    89.52%
# 5             Random Forest (Testing Set Prediction)   90.26%    91.71%
# 6                         XGBoost (Cross-Validation)   89.74%    90.41%
# 7                   XGBoost (Testing Set Prediction)   91.22%    91.62%
#
#    recall f1_score roc_auc_score
# 0  80.15%   73.82%          0.72
# 1  85.41%   82.92%          0.83
# 2  76.22%    80.0%          0.84
# 3   80.6%   81.89%          0.82
# 4  85.41%   87.41%          0.95
# 5  88.12%   89.88%           0.9
# 6  89.19%    89.8%          0.95
# 7  90.38%   90.99%          0.91
